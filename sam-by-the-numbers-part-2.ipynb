# %% [markdown]
# <a id="header"></a>
# # Part 2: levels 50-51
#
# [Return home](../)

# %%
from samurai import *
from plotting import *

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sb
from IPython.display import display
# %matplotlib inline

pd.options.display.max_rows = None

# %% [markdown]
# ## lvl 50

# %% [markdown]
# Level 50 unlocks the final weaponskill, Yukikaze, a combo finisher to open the final Sen, Setsu. It combos from Hakaze so it is a two hit combo contrary to Gekko and Kasha. Level 50 also confers the Meikyo Shisui ability, a cooldown that allows you to execute up to 3 combo abilities without meeting combo prerequisites. This may be used, for example, to quickly get Jinpu and Shifu buffs up or to open up all three Sen in a fraction of the time as normal.
#
# Furthermore, the opening of the final Sen unlocks the final Iaijutsu, Midare Setsugekka. This powerful single target nuke gives the opportunity in single target situations to deal massive damage without having to clip Higanbana.

# %% [markdown]
# Let's explore opener options.

# %% [markdown]
# ## Opener 1
# Buff first: Shifu > Jinpu > Yukikaze.
#
# Iaijutsu: Higanbana > Midare Setsugekka.
#
# Meikyo Shisui: generate second Midare Setsugekka.

# %%
sam = Samurai()

n_targets = 1

actions = [('Hakaze'), ('Shifu'), ('Kasha'), ('Hakaze'),
           ('Jinpu'), ('Higanbana'), ('Gekko'), ('Hakaze'),
           ('Yukikaze'), ('Hakaze'), ('Shifu'), ('Kasha'),
           ('Midare Setsugekka', 'Meikyo Shisui'), ('Kasha'), ('Gekko'), ('Yukikaze'), 
           ('Midare Setsugekka'), ('Hakaze'), ('Jinpu')]

# %%
df0, average_potency, pps = sam.parse_rotation(actions)
df0.set_index(['Time'])
display(df0)
# Out:
# average potency per GCD = 415.500578947
# average potency per second = 191.242999031
#      Time        Weaponskill        Ability  Potency  Jinpu  Shifu Yukikaze  \
# 0    0.00             Hakaze                 150.000  False  False    False
# 1    2.40              Shifu                 280.000  False  False    False
# 2    4.56              Kasha                 400.000  False   True    False
# 3    6.72             Hakaze                 150.000  False   True    False
# 4    8.88              Jinpu                 280.000  False   True    False
# 5   11.04          Higanbana                 276.000   True   True    False
# 6   13.20              Gekko                 493.327   True   True    False
# 7   15.36             Hakaze                 205.827   True   True    False
# 8   17.52           Yukikaze                 424.327   True   True    False
# 9   19.68             Hakaze                 224.802   True   True     True
# 10  21.84              Shifu                 390.747   True   True     True
# 11  24.00              Kasha                 543.927   True   True     True
# 12  26.16  Midare Setsugekka  Meikyo Shisui  952.407   True   True     True
# 13  28.32              Kasha                 543.927   True   True     True
# 14  30.48              Gekko                 543.927   True   True     True
# 15  32.64           Yukikaze                 467.337   True   True     True
# 16  34.80  Midare Setsugekka                 952.407   True   True     True
# 17  36.96             Hakaze                 224.802   True   True     True
# 18  39.12              Jinpu                 390.747  False   True     True
#
#     Higanbana  Kenki  Total Potency
# 0           0      0        150.000
# 1           0      0        430.000
# 2           0      0        830.000
# 3           0     10        980.000
# 4           0     10       1260.000
# 5           0     10       1536.000
# 6           1     10       2029.327
# 7           1     20       2235.154
# 8           1     20       2659.481
# 9           1     30       2884.283
# 10          1     30       3275.030
# 11          1     30       3818.957
# 12          1     40       4771.364
# 13          1     40       5315.291
# 14          1     50       5859.218
# 15          1     60       6326.555
# 16          1     70       7278.962
# 17          1     70       7503.764
# 18          1     70       7894.511

# %%
plot_potency(df0)

# %% [markdown]
# ## Opener 2
# Similar to Opener 1, just prioritize Jinpu > Shifu > Yukikaze so that the Higanbana DoT is buffed earlier.

# %%
sam = Samurai()

n_targets = 1

actions = [('Hakaze'), ('Jinpu'), ('Gekko'), ('Higanbana'),
           ('Hakaze'), ('Shifu'), ('Kasha'), ('Hakaze'),
           ('Yukikaze'), ('Hakaze'), ('Jinpu'), ('Gekko'),
           ('Midare Setsugekka', 'Meikyo Shisui'), ('Kasha'), ('Gekko'), ('Yukikaze'),
           ('Midare Setsugekka'), ('Hakaze'), ('Jinpu')]

# %%
df1, average_potency, pps = sam.parse_rotation(actions)
display(df1)
# Out:
# average potency per GCD = 425.951105263
# average potency per second = 191.597324811
#      Time        Weaponskill        Ability  Potency  Jinpu  Shifu Yukikaze  \
# 0    0.00             Hakaze                 150.000  False  False    False
# 1    2.40              Jinpu                 280.000  False  False    False
# 2    4.80              Gekko                 460.000   True  False    False
# 3    7.20          Higanbana                 276.000   True  False    False
# 4    9.60             Hakaze                 209.530   True  False    False
# 5   12.00              Shifu                 359.030   True  False    False
# 6   14.16              Kasha                 493.327   True   True    False
# 7   16.32             Hakaze                 205.827   True   True    False
# 8   18.48           Yukikaze                 424.327   True   True    False
# 9   20.64             Hakaze                 224.802   True   True     True
# 10  22.80              Jinpu                 390.747   True   True     True
# 11  24.96              Gekko                 543.927   True   True     True
# 12  27.12  Midare Setsugekka  Meikyo Shisui  952.407   True   True     True
# 13  29.28              Kasha                 543.927   True   True     True
# 14  31.44              Gekko                 543.927   True   True     True
# 15  33.60           Yukikaze                 467.337   True   True     True
# 16  35.76  Midare Setsugekka                 952.407   True   True     True
# 17  37.92             Hakaze                 224.802   True   True     True
# 18  40.08              Jinpu                 390.747   True   True     True
#
#     Higanbana  Kenki  Total Potency
# 0           0      0        150.000
# 1           0      0        430.000
# 2           0      0        890.000
# 3           0     10       1166.000
# 4           1     10       1375.530
# 5           1     10       1734.560
# 6           1     10       2227.887
# 7           1     20       2433.714
# 8           1     20       2858.041
# 9           1     30       3082.843
# 10          1     30       3473.590
# 11          1     30       4017.517
# 12          1     40       4969.924
# 13          1     40       5513.851
# 14          1     50       6057.778
# 15          1     60       6525.115
# 16          1     70       7477.522
# 17          1     70       7702.324
# 18          1     70       8093.071

# %%
plot_potency(df1)

# %% [markdown]
# ## Opener 3
# Meikyo Shisui: Get buffs up ASAP. Since Iaijutsu consumes one charge of Meikyo Shisui, we must delay Higanbana.
#
# Buffs first: Shifu > Jinpu > Yukikaze.
#
# Iaijutsu: Midare Setsugekka > Higanbana.

# %%
sam = Samurai()

n_targets = 1

actions = [('Hakaze'), ('Shifu'), ('Kasha', 'Meikyo Shisui'),
           ('Jinpu'), ('Gekko'), ('Yukikaze'), ('Midare Setsugekka'),
           ('Hakaze'), ('Yukikaze'), ('Higanbana'), ('Hakaze'),
           ('Shifu'), ('Kasha'), ('Hakaze'), ('Jinpu'),
           ('Gekko'), ('Hakaze'), ('Yukikaze'), ('Midare Setsugekka')]

# %%
df2, average_potency, pps = sam.parse_rotation(actions)
display(df2)
# Out:
# average potency per GCD = 409.232789474
# average potency per second = 188.35811531
#      Time        Weaponskill        Ability  Potency  Jinpu  Shifu Yukikaze  \
# 0    0.00             Hakaze                 150.000  False  False    False
# 1    2.40              Shifu                 280.000  False  False    False
# 2    4.56              Kasha  Meikyo Shisui  400.000  False   True    False
# 3    6.72              Jinpu                 280.000  False   True    False
# 4    8.88              Gekko                 460.000   True   True    False
# 5   11.04           Yukikaze                 391.000   True   True    False
# 6   13.20  Midare Setsugekka                 919.080   True   True     True
# 7   15.36             Hakaze                 191.475   True   True     True
# 8   17.52           Yukikaze                 434.010   True   True     True
# 9   19.68          Higanbana                 306.360   True   True     True
# 10  21.84             Hakaze                 224.802   True   True     True
# 11  24.00              Shifu                 390.747   True   True     True
# 12  26.16              Kasha                 543.927   True   True     True
# 13  28.32             Hakaze                 224.802   True   True     True
# 14  30.48              Jinpu                 390.747   True   True     True
# 15  32.64              Gekko                 543.927   True   True     True
# 16  34.80             Hakaze                 224.802   True   True     True
# 17  36.96           Yukikaze                 467.337   True   True     True
# 18  39.12  Midare Setsugekka                 952.407   True   True     True
#
#     Higanbana  Kenki  Total Potency
# 0           0      0        150.000
# 1           0      0        430.000
# 2           0      0        830.000
# 3           0     10       1110.000
# 4           0     10       1570.000
# 5           0     20       1961.000
# 6           0     30       2880.080
# 7           0     30       3071.555
# 8           0     30       3505.565
# 9           0     40       3811.925
# 10          1     40       4036.727
# 11          1     40       4427.474
# 12          1     40       4971.401
# 13          1     50       5196.203
# 14          1     50       5586.950
# 15          1     50       6130.877
# 16          1     60       6355.679
# 17          1     60       6823.016
# 18          1     70       7775.423

# %%
plot_potency(df2)

# %% [markdown]
# ## Opener 4
# Buffs up first: Shifu > Jinpu > Yukikaze
#
# Iaijutsu: Midare Setsugekka > Higanbana
#
# Meikyo Shisui: Generate second Midare Setsugekka

# %%
sam = Samurai()

n_targets = 1

actions = [('Hakaze'), ('Shifu'), ('Kasha'), ('Hakaze'),
           ('Jinpu'), ('Gekko'), ('Hakaze'), ('Yukikaze'),
           ('Midare Setsugekka'), ('Hakaze'), ('Shifu'), ('Kasha'),
           ('Higanbana', 'Meikyo Shisui'), ('Kasha'), ('Gekko'), ('Yukikaze'),
           ('Midare Setsugekka'), ('Hakaze'), ('Jinpu')]

# %%
df3, average_potency, pps = sam.parse_rotation(actions)
display(df3)
# Out:
# average potency per GCD = 404.820105263
# average potency per second = 186.327083333
#      Time        Weaponskill        Ability  Potency  Jinpu  Shifu Yukikaze  \
# 0    0.00             Hakaze                 150.000  False  False    False
# 1    2.40              Shifu                 280.000  False  False    False
# 2    4.56              Kasha                 400.000  False   True    False
# 3    6.72             Hakaze                 150.000  False   True    False
# 4    8.88              Jinpu                 280.000  False   True    False
# 5   11.04              Gekko                 460.000   True   True    False
# 6   13.20             Hakaze                 172.500   True   True    False
# 7   15.36           Yukikaze                 391.000   True   True    False
# 8   17.52  Midare Setsugekka                 919.080   True   True     True
# 9   19.68             Hakaze                 191.475   True   True     True
# 10  21.84              Shifu                 357.420   True   True     True
# 11  24.00              Kasha                 510.600   True   True     True
# 12  26.16          Higanbana  Meikyo Shisui  306.360   True   True     True
# 13  28.32              Kasha                 543.927   True   True     True
# 14  30.48              Gekko                 543.927   True   True     True
# 15  32.64           Yukikaze                 467.337   True   True     True
# 16  34.80  Midare Setsugekka                 952.407   True   True     True
# 17  36.96             Hakaze                 224.802   True   True     True
# 18  39.12              Jinpu                 390.747  False   True     True
#
#     Higanbana  Kenki  Total Potency
# 0           0      0        150.000
# 1           0      0        430.000
# 2           0      0        830.000
# 3           0     10        980.000
# 4           0     10       1260.000
# 5           0     10       1720.000
# 6           0     20       1892.500
# 7           0     20       2283.500
# 8           0     30       3202.580
# 9           0     30       3394.055
# 10          0     30       3751.475
# 11          0     30       4262.075
# 12          0     40       4568.435
# 13          1     40       5112.362
# 14          1     50       5656.289
# 15          1     60       6123.626
# 16          1     70       7076.033
# 17          1     70       7300.835
# 18          1     70       7691.582

# %%
plot_potency(df3)

# %% [markdown]
# ## Opener 5
# Similar to Openers 1 and 2, but prioritizes Yukikaze > Shifu > Jinpu. This lets you put Higanbana one GCD earlier and, for parties without WAR, gets the slashing resistance down debuff up faster. A NIN may possibly get it up faster or at the same time if it opens with Shadow Fang combo due to Huton.

# %%
sam = Samurai()

n_targets = 1

actions = [('Hakaze'), ('Yukikaze'), ('Higanbana'), ('Hakaze'),
           ('Shifu'), ('Kasha'), ('Hakaze'), ('Jinpu'),
           ('Gekko'), ('Hakaze'), ('Yukikaze'), ('Midare Setsugekka', 'Meikyo Shisui'),
           ('Kasha'), ('Gekko'), ('Yukikaze'), ('Midare Setsugekka'),
           ('Hakaze'), ('Shifu'), ('Kasha')]

# %%
df4, average_potency, pps = sam.parse_rotation(actions)
display(df4)
# Out:
# average potency per GCD = 426.216315789
# average potency per second = 192.812142857
#      Time        Weaponskill        Ability  Potency  Jinpu  Shifu Yukikaze  \
# 0    0.00             Hakaze                 150.000  False  False    False
# 1    2.40           Yukikaze                 340.000  False  False    False
# 2    4.80          Higanbana                 266.400  False  False     True
# 3    7.20             Hakaze                 194.500  False  False     True
# 4    9.60              Shifu                 338.800  False  False     True
# 5   11.76              Kasha                 469.200  False   True     True
# 6   13.92             Hakaze                 191.700  False   True     True
# 7   16.08              Jinpu                 339.780  False   True     True
# 8   18.24              Gekko                 539.580   True   True     True
# 9   20.40             Hakaze                 220.455   True   True     True
# 10  22.56           Yukikaze                 462.990   True   True     True
# 11  24.72  Midare Setsugekka  Meikyo Shisui  948.060   True   True     True
# 12  26.88              Kasha                 539.580   True   True     True
# 13  29.04              Gekko                 539.580   True   True     True
# 14  31.20           Yukikaze                 462.990   True   True     True
# 15  33.36  Midare Setsugekka                 948.060   True   True     True
# 16  35.52             Hakaze                 220.455   True   True     True
# 17  37.68              Shifu                 386.400   True   True     True
# 18  39.84              Kasha                 539.580   True   True     True
#
#     Higanbana  Kenki  Total Potency
# 0           0      0        150.000
# 1           0      0        490.000
# 2           0     10        756.400
# 3           1     10        950.900
# 4           1     10       1289.700
# 5           1     10       1758.900
# 6           1     20       1950.600
# 7           1     20       2290.380
# 8           1     20       2829.960
# 9           1     30       3050.415
# 10          1     30       3513.405
# 11          1     40       4461.465
# 12          1     40       5001.045
# 13          1     50       5540.625
# 14          1     60       6003.615
# 15          1     70       6951.675
# 16          1     70       7172.130
# 17          1     70       7558.530
# 18          1     70       8098.110

# %%
plot_potency(df4)

# %%
dfs = [df4, df3, df2, df1, df0]
labels = ['Opener 5', 'Opener 4', 'Opener 3', 'Opener 2', 'Opener 1']
compare_n_potencies(dfs, labels)

# %% [markdown]
# The time horizon was selected so that each opener had at least two Midare Setsugekka.

# %% [markdown]
# These openers have fairly similar cumulative potencies over the selected time horizon. At level 50, you have no other offensive cooldowns when considering buff alignment. Party synergies will need to be considered to determine the best placement. (Maximizing potency delivered under party buffs.) Higanbana is applied at a different time and each opener bursts at different times. Since Higanbana and Midare Setsugekka have the highest effective potency per GCD (with DoT snapshot), getting those Iaijutsu under party buffs will differentiate these openers' potency significantly.

# %%
fig, ax = plt.subplots(figsize=(12, 4))

for k, df in enumerate(dfs):
    ax.plot(df['Time'], df['Potency'], label=labels[k])
    ax.set_xlabel('Time')
    ax.set_ylabel('Potency')
    ax.legend(loc='upper left', framealpha=0.5)

fig.suptitle('Opener Potency over Time')
fig.tight_layout(pad=3)

# %% [markdown]
# ### Priority: Shifu > Jinpu > Yukikaze and Higanbana > Midare Setsugekka
# Since Yukikaze is applied to the target, refreshing it on a dying target is lesser of a priority. However, since it is necessary to open Setsu, it cannot be neglected.
#
# ### Filler: Combos to refresh buffs, avoid wasting Sen.
#
# ### AoE: Similar as lvl 40-49... avoid using Yukikaze in large pulls due to it being a target debuff, not a self buff.
# You will probably be using the AoE weaponskills -> Tenka Goken rotation anyway.

# %% [markdown]
# ## Extended simulations

# %% [markdown]
# Openers are fine to look at it in a vacuum, but cooldown and buff alignment is difficult to see over short time horizons; do the buff/cooldown timings set you up nicely for the rest of the encounter? Let's look at how these openers transition into the priority system and look at an example of how a long single target encounter may go.

# %% [markdown]
# ### With Opener 5
# This opener had the highest average potency by a slim margin.

# %%
sam = Samurai()

n_targets = 1

actions = [('Hakaze'), ('Yukikaze'), ('Higanbana'), ('Hakaze'),
           ('Shifu'), ('Kasha'), ('Hakaze'), ('Jinpu'),
           ('Gekko'), ('Hakaze'), ('Yukikaze'), ('Midare Setsugekka', 'Meikyo Shisui'),
           ('Kasha'), ('Gekko'), ('Yukikaze'), ('Midare Setsugekka'),
           ('Hakaze'), ('Shifu'), ('Kasha'), ('Hakaze'), 
           ('Jinpu'), ('Gekko'), ('Hakaze'), ('Yukikaze'),
           ('Midare Setsugekka'), ('Hakaze'), ('Shifu'), ('Kasha'),
           ('Higanbana'), ('Hakaze'), ('Jinpu'), ('Gekko'),
           ('Hakaze'), ('Yukikaze'), ('Hakaze'), ('Shifu'),
           ('Kasha'), ('Midare Setsugekka'), ('Hakaze'), ('Jinpu'),
           ('Gekko'), ('Hakaze'), ('Yukikaze'), ('Hakaze'),
           ('Shifu'), ('Kasha'), ('Midare Setsugekka'), ('Hakaze'), # Meikyo Shisui should be coming off c/d next.
           ('Jinpu'), ('Gekko'), ('Hakaze'), ('Yukikaze'),
           ('Hakaze'), ('Shifu'), ('Kasha'), ('Midare Setsugekka'), # Higanbana DoT should be falling off...
           ('Hakaze'), ('Jinpu'), ('Gekko'), ('Higanbana', 'Meikyo Shisui'),
           ('Yukikaze'), ('Kasha'), ('Gekko'), ('Midare Setsugekka')]

# %%
df4_ext, average_potency, pps = sam.parse_rotation(actions)
display(df4_ext)
# Out:
# average potency per GCD = 439.923421875
# average potency per second = 202.263642241
#       Time        Weaponskill        Ability  Potency  Jinpu  Shifu Yukikaze  \
# 0     0.00             Hakaze                 150.000  False  False    False
# 1     2.40           Yukikaze                 340.000  False  False    False
# 2     4.80          Higanbana                 266.400  False  False     True
# 3     7.20             Hakaze                 194.500  False  False     True
# 4     9.60              Shifu                 338.800  False  False     True
# 5    11.76              Kasha                 469.200  False   True     True
# 6    13.92             Hakaze                 191.700  False   True     True
# 7    16.08              Jinpu                 339.780  False   True     True
# 8    18.24              Gekko                 539.580   True   True     True
# 9    20.40             Hakaze                 220.455   True   True     True
# 10   22.56           Yukikaze                 462.990   True   True     True
# 11   24.72  Midare Setsugekka  Meikyo Shisui  948.060   True   True     True
# 12   26.88              Kasha                 539.580   True   True     True
# 13   29.04              Gekko                 539.580   True   True     True
# 14   31.20           Yukikaze                 462.990   True   True     True
# 15   33.36  Midare Setsugekka                 948.060   True   True     True
# 16   35.52             Hakaze                 220.455   True   True     True
# 17   37.68              Shifu                 386.400   True   True     True
# 18   39.84              Kasha                 539.580   True   True     True
# 19   42.00             Hakaze                 220.455   True   True     True
# 20   44.16              Jinpu                 386.400   True   True     True
# 21   46.32              Gekko                 539.580   True   True     True
# 22   48.48             Hakaze                 220.455   True   True     True
# 23   50.64           Yukikaze                 462.990   True   True     True
# 24   52.80  Midare Setsugekka                 948.060   True   True     True
# 25   54.96             Hakaze                 220.455   True   True     True
# 26   57.12              Shifu                 386.400   True   True     True
# 27   59.28              Kasha                 539.580   True   True     True
# 28   61.44          Higanbana                 335.340   True   True     True
# 29   63.60             Hakaze                 224.802   True   True     True
# 30   65.76              Jinpu                 390.747   True   True     True
# 31   67.92              Gekko                 543.927   True   True     True
# 32   70.08             Hakaze                 224.802   True   True     True
# 33   72.24           Yukikaze                 467.337   True   True     True
# 34   74.40             Hakaze                 224.802   True   True     True
# 35   76.56              Shifu                 390.747   True   True     True
# 36   78.72              Kasha                 543.927   True   True     True
# 37   80.88  Midare Setsugekka                 952.407   True   True     True
# 38   83.04             Hakaze                 224.802   True   True     True
# 39   85.20              Jinpu                 390.747   True   True     True
# 40   87.36              Gekko                 543.927   True   True     True
# 41   89.52             Hakaze                 224.802   True   True     True
# 42   91.68           Yukikaze                 467.337   True   True     True
# 43   93.84             Hakaze                 224.802   True   True     True
# 44   96.00              Shifu                 390.747   True   True     True
# 45   98.16              Kasha                 543.927   True   True     True
# 46  100.32  Midare Setsugekka                 952.407   True   True     True
# 47  102.48             Hakaze                 224.802   True   True     True
# 48  104.64              Jinpu                 390.747   True   True     True
# 49  106.80              Gekko                 543.927   True   True     True
# 50  108.96             Hakaze                 224.802   True   True     True
# 51  111.12           Yukikaze                 467.337   True   True     True
# 52  113.28             Hakaze                 224.802   True   True     True
# 53  115.44              Shifu                 390.747   True   True     True
# 54  117.60              Kasha                 543.927   True   True     True
# 55  119.76  Midare Setsugekka                 952.407   True   True     True
# 56  121.92             Hakaze                 224.802   True   True     True
# 57  124.08              Jinpu                 357.420   True   True     True
# 58  126.24              Gekko                 510.600   True   True     True
# 59  128.40          Higanbana  Meikyo Shisui  306.360   True   True     True
# 60  130.56           Yukikaze                 467.337   True   True     True
# 61  132.72              Kasha                 543.927   True   True     True
# 62  134.88              Gekko                 543.927   True   True     True
# 63  137.04  Midare Setsugekka                 952.407   True   True     True
#
#     Higanbana  Kenki  Total Potency
# 0           0      0        150.000
# 1           0      0        490.000
# 2           0     10        756.400
# 3           1     10        950.900
# 4           1     10       1289.700
# 5           1     10       1758.900
# 6           1     20       1950.600
# 7           1     20       2290.380
# 8           1     20       2829.960
# 9           1     30       3050.415
# 10          1     30       3513.405
# 11          1     40       4461.465
# 12          1     40       5001.045
# 13          1     50       5540.625
# 14          1     60       6003.615
# 15          1     70       6951.675
# 16          1     70       7172.130
# 17          1     70       7558.530
# 18          1     70       8098.110
# 19          1     80       8318.565
# 20          1     80       8704.965
# 21          1     80       9244.545
# 22          1     90       9465.000
# 23          1     90       9927.990
# 24          1    100      10876.050
# 25          1    100      11096.505
# 26          1    100      11482.905
# 27          1    100      12022.485
# 28          1    100      12357.825
# 29          1    100      12582.627
# 30          1    100      12973.374
# 31          1    100      13517.301
# 32          1    100      13742.103
# 33          1    100      14209.440
# 34          1    100      14434.242
# 35          1    100      14824.989
# 36          1    100      15368.916
# 37          1    100      16321.323
# 38          1    100      16546.125
# 39          1    100      16936.872
# 40          1    100      17480.799
# 41          1    100      17705.601
# 42          1    100      18172.938
# 43          1    100      18397.740
# 44          1    100      18788.487
# 45          1    100      19332.414
# 46          1    100      20284.821
# 47          1    100      20509.623
# 48          1    100      20900.370
# 49          1    100      21444.297
# 50          1    100      21669.099
# 51          1    100      22136.436
# 52          1    100      22361.238
# 53          1    100      22751.985
# 54          1    100      23295.912
# 55          1    100      24248.319
# 56          1    100      24473.121
# 57          0    100      24830.541
# 58          0    100      25341.141
# 59          0    100      25647.501
# 60          1    100      26114.838
# 61          1    100      26658.765
# 62          1    100      27202.692
# 63          1    100      28155.099

# %%
plot_potency(df4_ext, truncate_actions=True)

# %% [markdown]
# Interestingly enough, the average potency this long into the encounter is actually higher than after the opener. This can be attributed to the lack of stacking damage buffs that we can blow into the opener.
#
# One observed issue through this simulation is the timing of Higanbana's DoT and Meikyo Shisui coming off cooldown. As commented in the actions list, Meikyo Shisui comes off cooldown for quite a while before an optimal time to use it is presented. It should be off cooldown at around index 48; this is right before a Sen is opened via combo finisher. With the MO of using Meikyo Shisui exclusively to open three Sen in a row, this means we must wait until after we naturally open these Sen (at index 54). Furthermore, the third Higanbana is due to be applied at approximately index 55. Since this is when Midare Setsugekka is ready, we must delay. At this juncture, we must decide if we let Higanbana's DoT fall off for four more GCDs (about 3-4 ticks) in order to to get Meikyo Shisui back on cooldown after a double Midare Setsugekka. The other option would be to get Higanbana applied ASAP.
#
# The usual answer for this dilemma is constrained by the number of Meikyo Shisui uses available in the encounter. If delaying using Meikyo Shisui too long results in one less use of it, then we should lean towards letting Higanbana drop a few ticks if it lets us use Meikyo Shisui sooner.

# %% [markdown]
# ### With Opener 3
# This opener had the lowest average potency, but got buffs up faster and got Meikyo Shisui on cooldown the soonest. This difference in buff/DoT timing is worth exploring

# %%
sam = Samurai()

n_targets = 1

actions = [('Hakaze'), ('Shifu'), ('Kasha', 'Meikyo Shisui'),
           ('Jinpu'), ('Gekko'), ('Yukikaze'), ('Midare Setsugekka'),
           ('Hakaze'), ('Yukikaze'), ('Higanbana'), ('Hakaze'),
           ('Shifu'), ('Kasha'), ('Hakaze'), ('Jinpu'),
           ('Gekko'), ('Hakaze'), ('Yukikaze'), ('Midare Setsugekka'),
           ('Hakaze'), ('Shifu'), ('Kasha'), ('Hakaze'),
           ('Jinpu'), ('Gekko'), ('Hakaze'), ('Yukikaze'),
           ('Midare Setsugekka'), ('Hakaze'), ('Shifu'), ('Kasha'),
           ('Hakaze'), ('Jinpu'), ('Gekko'), ('Hakaze'),
           ('Yukikaze'), ('Midare Setsugekka'), ('Hakaze'), ('Shifu'),
           ('Kasha'), ('Higanbana', 'Meikyo Shisui'), ('Gekko'), ('Yukikaze'),
           ('Kasha'), ('Midare Setsugekka'), ('Hakaze'), ('Jinpu'),
           ('Gekko'), ('Hakaze'), ('Shifu'), ('Kasha'),
           ('Hakaze'), ('Yukikaze'), ('Midare Setsugekka'), ('Hakaze'),
           ('Jinpu'), ('Gekko'), ('Hakaze'), ('Shifu'),
           ('Kasha'), ('Hakaze'), ('Yukikaze'), ('Midare Setsugekka')]

# %%
df2_ext, average_potency, pps = sam.parse_rotation(actions)
display(df2_ext)
# Out:
# average potency per GCD = 437.082460317
# average potency per second = 201.996735622
#       Time        Weaponskill        Ability  Potency  Jinpu  Shifu Yukikaze  \
# 0     0.00             Hakaze                 150.000  False  False    False
# 1     2.40              Shifu                 280.000  False  False    False
# 2     4.56              Kasha  Meikyo Shisui  400.000  False   True    False
# 3     6.72              Jinpu                 280.000  False   True    False
# 4     8.88              Gekko                 460.000   True   True    False
# 5    11.04           Yukikaze                 391.000   True   True    False
# 6    13.20  Midare Setsugekka                 919.080   True   True     True
# 7    15.36             Hakaze                 191.475   True   True     True
# 8    17.52           Yukikaze                 434.010   True   True     True
# 9    19.68          Higanbana                 306.360   True   True     True
# 10   21.84             Hakaze                 224.802   True   True     True
# 11   24.00              Shifu                 390.747   True   True     True
# 12   26.16              Kasha                 543.927   True   True     True
# 13   28.32             Hakaze                 224.802   True   True     True
# 14   30.48              Jinpu                 390.747   True   True     True
# 15   32.64              Gekko                 543.927   True   True     True
# 16   34.80             Hakaze                 224.802   True   True     True
# 17   36.96           Yukikaze                 467.337   True   True     True
# 18   39.12  Midare Setsugekka                 952.407   True   True     True
# 19   41.28             Hakaze                 224.802   True   True     True
# 20   43.44              Shifu                 390.747   True   True     True
# 21   45.60              Kasha                 543.927   True   True     True
# 22   47.76             Hakaze                 224.802   True   True     True
# 23   49.92              Jinpu                 390.747   True   True     True
# 24   52.08              Gekko                 543.927   True   True     True
# 25   54.24             Hakaze                 224.802   True   True     True
# 26   56.40           Yukikaze                 467.337   True   True     True
# 27   58.56  Midare Setsugekka                 952.407   True   True     True
# 28   60.72             Hakaze                 224.802   True   True     True
# 29   62.88              Shifu                 390.747   True   True     True
# 30   65.04              Kasha                 543.927   True   True     True
# 31   67.20             Hakaze                 224.802   True   True     True
# 32   69.36              Jinpu                 390.747   True   True     True
# 33   71.52              Gekko                 543.927   True   True     True
# 34   73.68             Hakaze                 224.802   True   True     True
# 35   75.84           Yukikaze                 467.337   True   True     True
# 36   78.00  Midare Setsugekka                 952.407   True   True     True
# 37   80.16             Hakaze                 224.802   True   True     True
# 38   82.32              Shifu                 357.420   True   True     True
# 39   84.48              Kasha                 510.600   True   True     True
# 40   86.64          Higanbana  Meikyo Shisui  306.360   True   True     True
# 41   88.80              Gekko                 543.927   True   True     True
# 42   90.96           Yukikaze                 467.337   True   True     True
# 43   93.12              Kasha                 543.927   True   True     True
# 44   95.28  Midare Setsugekka                 952.407   True   True     True
# 45   97.44             Hakaze                 224.802   True   True     True
# 46   99.60              Jinpu                 390.747  False   True     True
# 47  101.76              Gekko                 543.927   True   True     True
# 48  103.92             Hakaze                 224.802   True   True     True
# 49  106.08              Shifu                 390.747   True   True     True
# 50  108.24              Kasha                 543.927   True   True     True
# 51  110.40             Hakaze                 224.802   True   True     True
# 52  112.56           Yukikaze                 467.337   True   True     True
# 53  114.72  Midare Setsugekka                 952.407   True   True     True
# 54  116.88             Hakaze                 224.802   True   True     True
# 55  119.04              Jinpu                 390.747   True   True     True
# 56  121.20              Gekko                 543.927   True   True     True
# 57  123.36             Hakaze                 224.802   True   True     True
# 58  125.52              Shifu                 390.747   True   True     True
# 59  127.68              Kasha                 543.927   True   True     True
# 60  129.84             Hakaze                 224.802   True   True     True
# 61  132.00           Yukikaze                 467.337   True   True     True
# 62  134.16  Midare Setsugekka                 952.407   True   True     True
#
#     Higanbana  Kenki  Total Potency
# 0           0      0        150.000
# 1           0      0        430.000
# 2           0      0        830.000
# 3           0     10       1110.000
# 4           0     10       1570.000
# 5           0     20       1961.000
# 6           0     30       2880.080
# 7           0     30       3071.555
# 8           0     30       3505.565
# 9           0     40       3811.925
# 10          1     40       4036.727
# 11          1     40       4427.474
# 12          1     40       4971.401
# 13          1     50       5196.203
# 14          1     50       5586.950
# 15          1     50       6130.877
# 16          1     60       6355.679
# 17          1     60       6823.016
# 18          1     70       7775.423
# 19          1     70       8000.225
# 20          1     70       8390.972
# 21          1     70       8934.899
# 22          1     80       9159.701
# 23          1     80       9550.448
# 24          1     80      10094.375
# 25          1     90      10319.177
# 26          1     90      10786.514
# 27          1    100      11738.921
# 28          1    100      11963.723
# 29          1    100      12354.470
# 30          1    100      12898.397
# 31          1    100      13123.199
# 32          1    100      13513.946
# 33          1    100      14057.873
# 34          1    100      14282.675
# 35          1    100      14750.012
# 36          1    100      15702.419
# 37          1    100      15927.221
# 38          0    100      16284.641
# 39          0    100      16795.241
# 40          0    100      17101.601
# 41          1    100      17645.528
# 42          1    100      18112.865
# 43          1    100      18656.792
# 44          1    100      19609.199
# 45          1    100      19834.001
# 46          1    100      20224.748
# 47          1    100      20768.675
# 48          1    100      20993.477
# 49          1    100      21384.224
# 50          1    100      21928.151
# 51          1    100      22152.953
# 52          1    100      22620.290
# 53          1    100      23572.697
# 54          1    100      23797.499
# 55          1    100      24188.246
# 56          1    100      24732.173
# 57          1    100      24956.975
# 58          1    100      25347.722
# 59          1    100      25891.649
# 60          1    100      26116.451
# 61          1    100      26583.788
# 62          1    100      27536.195

# %% [markdown]
# The timing here is better. An optimal window for Meikyo Shisui presents itself right after it comes off cooldown. We do end up dropping Higanbana DoT for about 7 seconds though, although that was the case in the previous rotation. The overall potency per second or potency per GCD are similar.

# %%
compare_potencies([df4_ext, df2_ext], labels=['With Opener 5', 'With Opener 3'])

# %% [markdown]
# Ultimately, with only weaponskills to play with, one buff, and one DoT, there is a limited degree of complexity in the single target rotation at level 50. Following the described priority system for weaponskills, using Iaijutsu intelligently, and keeping the GCD moving, you will be close to optimal output.

# %% [markdown]
# <a href="#header">back to the top...</a>
